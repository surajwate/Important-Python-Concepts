# %% [markdown]
# # Pandas Tutorial

# %% [markdown]
# ## 1. Installation and Loading Data

# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')

# %%
df.shape
# Out:
# (88883, 84)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88883 entries, 1 to 88863
# Data columns (total 84 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   MainBranch              88331 non-null  object
#  1   Hobbyist                88883 non-null  object
#  2   OpenSourcer             88883 non-null  object
#  3   OpenSource              86842 non-null  object
#  4   Employment              87181 non-null  object
#  5   Country                 88751 non-null  object
#  6   Student                 87014 non-null  object
#  7   EdLevel                 86390 non-null  object
#  8   UndergradMajor          75614 non-null  object
#  9   EduOther                84260 non-null  object
#  10  OrgSize                 71791 non-null  object
#  11  DevType                 81335 non-null  object
#  12  YearsCode               87938 non-null  object
#  13  Age1stCode              87634 non-null  object
# ...

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# ...

# %% [markdown]
# ## 2. Selecting Rows and Columns

# %%
people = {
    'first': ['Suraj', 'Tapan', 'Leon', 'Kushal'],
    'last' : ['Wate', 'Agrawal', 'Fernandes', 'Wate'],
    'email' : ['suraj.w@email.com', 'tapan.a@email.com', 'leon.f@email.com', 'kushal.w@email.com']
}

# %%
people_df = pd.DataFrame(people)

# %%
people_df
# Out:
#     first       last               email
# 0   Suraj       Wate   suraj.w@email.com
# 1   Tapan    Agrawal   tapan.a@email.com
# 2    Leon  Fernandes    leon.f@email.com
# 3  Kushal       Wate  kushal.w@email.com

# %% [markdown]
# ### Get column

# %%
# selecting column (which is a series)
people_df['email']
# Out:
# 0     suraj.w@email.com
# 1     tapan.a@email.com
# 2      leon.f@email.com
# 3    kushal.w@email.com
# Name: email, dtype: object

# %%
type(people_df['email'])
# Out:
# pandas.core.series.Series

# %%
# Same as above
people_df.email
# Out:
# 0     suraj.w@email.com
# 1     tapan.a@email.com
# 2      leon.f@email.com
# 3    kushal.w@email.com
# Name: email, dtype: object

# %%
people_df[['last', 'email']]
# Out:
#         last               email
# 0       Wate   suraj.w@email.com
# 1    Agrawal   tapan.a@email.com
# 2  Fernandes    leon.f@email.com
# 3       Wate  kushal.w@email.com

# %%
people_df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %% [markdown]
# ### To get the rows

# %%
people_df.iloc[0]
# Out:
# first                Suraj
# last                  Wate
# email    suraj.w@email.com
# Name: 0, dtype: object

# %%
people_df.iloc[[0, 1]]
# Out:
#    first     last              email
# 0  Suraj     Wate  suraj.w@email.com
# 1  Tapan  Agrawal  tapan.a@email.com

# %% [markdown]
# ### Get Specific rows and columns

# %%
people_df.iloc[[0, 1], 2]
# Out:
# 0    suraj.w@email.com
# 1    tapan.a@email.com
# Name: email, dtype: object

# %% [markdown]
# #### Using loc

# %%
people_df.loc[[0, 1], 'email']
# Out:
# 0    suraj.w@email.com
# 1    tapan.a@email.com
# Name: email, dtype: object

# %%
people_df.loc[[0, 2], ['email', 'last']]
# Out:
#                email       last
# 0  suraj.w@email.com       Wate
# 2   leon.f@email.com  Fernandes

# %%
df.shape
# Out:
# (88883, 84)

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df.loc[2, 'Hobbyist']
# Out:
# 'No'

# %%
df.loc[[4, 5, 8], 'Hobbyist']
# Out:
# Respondent
# 4     No
# 5    Yes
# 8    Yes
# Name: Hobbyist, dtype: object

# %%
# First three row

df.loc[1:3, 'Hobbyist':'Employment']
# Out:
#            Hobbyist              OpenSourcer  \
# Respondent
# 1               Yes                    Never
# 2                No  Less than once per year
# 3               Yes                    Never
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
#
#                                         Employment
# Respondent
# 1           Not employed, and not looking for work
# 2               Not employed, but looking for work
# 3                               Employed full-time

# %% [markdown]
# ## 3. Indexes - How to Set, Reset, and Use Indexes

# %%
people_df['email']
# Out:
# 0     suraj.w@email.com
# 1     tapan.a@email.com
# 2      leon.f@email.com
# 3    kushal.w@email.com
# Name: email, dtype: object

# %%
people_df.set_index('email')
# Out:
#                      first       last
# email
# suraj.w@email.com    Suraj       Wate
# tapan.a@email.com    Tapan    Agrawal
# leon.f@email.com      Leon  Fernandes
# kushal.w@email.com  Kushal       Wate

# %%
people_df
# Out:
#     first       last               email
# 0   Suraj       Wate   suraj.w@email.com
# 1   Tapan    Agrawal   tapan.a@email.com
# 2    Leon  Fernandes    leon.f@email.com
# 3  Kushal       Wate  kushal.w@email.com

# %%
people_df.set_index('email', inplace=True)

# %%
people_df
# Out:
#                      first       last
# email
# suraj.w@email.com    Suraj       Wate
# tapan.a@email.com    Tapan    Agrawal
# leon.f@email.com      Leon  Fernandes
# kushal.w@email.com  Kushal       Wate

# %%
people_df.index
# Out:
# Index(['suraj.w@email.com', 'tapan.a@email.com', 'leon.f@email.com',
#        'kushal.w@email.com'],
#       dtype='object', name='email')

# %%
people_df.loc['suraj.w@email.com']
# Out:
# first    Suraj
# last      Wate
# Name: suraj.w@email.com, dtype: object

# %% [markdown]
# ### Reset the index

# %%
people_df.reset_index(inplace=True)

# %%
people_df
# Out:
#                 email   first       last
# 0   suraj.w@email.com   Suraj       Wate
# 1   tapan.a@email.com   Tapan    Agrawal
# 2    leon.f@email.com    Leon  Fernandes
# 3  kushal.w@email.com  Kushal       Wate

# %% [markdown]
# ------------

# %%
schema_df.loc['Hobbyist']
# Out:
# QuestionText    Do you code as a hobby?
# Name: Hobbyist, dtype: object

# %%
schema_df.loc['MgrIdiot', 'QuestionText']
# Out:
# 'How confident are you that your manager knows what they’re doing?'

# %% [markdown]
# ### Sorting the dataframe by index

# %%
schema_df.sort_index(inplace=True)

# %%
schema_df.sort_index(ascending=False)
# Out:
#                                                              QuestionText
# Column
# YearsCodePro            How many years have you coded professionally (...
# YearsCode               Including any education, how many years have y...
# WorkWeekHrs              On average, how many hours per week do you work?
# WorkRemote                                How often do you work remotely?
# WorkPlan                          How structured or planned is your work?
# WorkLoc                                   Where would you prefer to work?
# WorkChallenge           Of these options, what are your greatest chall...
# WelcomeChange           Compared to last year, how welcome do you feel...
# WebFrameWorkedWith      Which of the following web frameworks have you...
# WebFrameDesireNextYear  Which of the following web frameworks have you...
# UnitTests               Does your company regularly employ unit tests ...
# UndergradMajor          What was your main or most important field of ...
# ...

# %% [markdown]
# ## 4. Filtering - Using conditionals to filter rows and columns

# %%
people_df['last'] == 'Agrawal'
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# Name: last, dtype: bool

# %%
filt = (people_df['last'] == 'Agrawal')

# %%
people_df[filt]
# Out:
#                email  first     last
# 1  tapan.a@email.com  Tapan  Agrawal

# %%
people_df[people_df['last'] == 'Agrawal']
# Out:
#                email  first     last
# 1  tapan.a@email.com  Tapan  Agrawal

# %%
people_df.loc[filt]
# Out:
#                email  first     last
# 1  tapan.a@email.com  Tapan  Agrawal

# %%
people_df.loc[filt, 'email']
# Out:
# 1    tapan.a@email.com
# Name: email, dtype: object

# %% [markdown]
# ### AND and OR operators

# %%
filt = (people_df['last'] == 'Wate') & (people_df['first'] == 'Kushal')

# %%
people_df.loc[filt, 'email']
# Out:
# 3    kushal.w@email.com
# Name: email, dtype: object

# %%
# NOT operator

people_df.loc[~filt, 'email']
# Out:
# 0    suraj.w@email.com
# 1    tapan.a@email.com
# 2     leon.f@email.com
# Name: email, dtype: object

# %% [markdown]
# ----------

# %%
high_salary = (df['ConvertedComp'] > 70000)

# %%
df.loc[high_salary, ['Country', 'LanguageWorkedWith', 'ConvertedComp']]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 6                   Canada                                         Java;R;SQL
# 9              New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 13           United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 16          United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 22           United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...                    ...                                                ...
# 88876        United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88877        United States  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88878        United States               HTML/CSS;JavaScript;Scala;TypeScript
# 88879              Finland                   Bash/Shell/PowerShell;C++;Python
# 88882          Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
# ...

# %%
countries  = ['United States', 'India', 'United Kingdon', 'Germany', 'Canada']
filt = df['Country'].isin(countries)

# %%
df.loc[filt, 'Country']
# Out:
# Respondent
# 4        United States
# 6               Canada
# 8                India
# 10               India
# 12              Canada
#              ...
# 85182           Canada
# 85642    United States
# 86012            India
# 88282    United States
# 88377           Canada
# Name: Country, Length: 39271, dtype: object

# %% [markdown]
# ### Filter Strings

# %%
df['LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 3                                                 HTML/CSS
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#                                ...
# 88377                        HTML/CSS;JavaScript;Other(s):
# 88601                                                  NaN
# 88802                                                  NaN
# 88816                                                  NaN
# 88863    Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# Name: LanguageWorkedWith, Length: 88883, dtype: object

# %%
filt = df['LanguageWorkedWith'].str.contains('Python', na=False)

# %%
df.loc[filt, 'LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 84539    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 85738      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 86566      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 87739             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88212                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %% [markdown]
# ------------

# %% [markdown]
# ## 5. Updating Rows and Columns - Modifying Data Within DataFrames

# %%
people_df
# Out:
#                 email   first       last
# 0   suraj.w@email.com   Suraj       Wate
# 1   tapan.a@email.com   Tapan    Agrawal
# 2    leon.f@email.com    Leon  Fernandes
# 3  kushal.w@email.com  Kushal       Wate

# %%
people_df.columns
# Out:
# Index(['email', 'first', 'last'], dtype='object')

# %%
people_df.columns = ['email', 'first_name', 'last_name']

# %%
people_df
# Out:
#                 email first_name  last_name
# 0   suraj.w@email.com      Suraj       Wate
# 1   tapan.a@email.com      Tapan    Agrawal
# 2    leon.f@email.com       Leon  Fernandes
# 3  kushal.w@email.com     Kushal       Wate

# %%
people_df.columns = [x.upper() for x in people_df.columns]
people_df
# Out:
#                 EMAIL FIRST_NAME  LAST_NAME
# 0   suraj.w@email.com      Suraj       Wate
# 1   tapan.a@email.com      Tapan    Agrawal
# 2    leon.f@email.com       Leon  Fernandes
# 3  kushal.w@email.com     Kushal       Wate

# %%
people_df.columns = people_df.columns.str.replace('_', ' ')
people_df
# Out:
#                 EMAIL FIRST NAME  LAST NAME
# 0   suraj.w@email.com      Suraj       Wate
# 1   tapan.a@email.com      Tapan    Agrawal
# 2    leon.f@email.com       Leon  Fernandes
# 3  kushal.w@email.com     Kushal       Wate

# %%
people_df.columns = [x.lower() for x in people_df.columns]
people_df.columns = people_df.columns.str.replace(' ', '_')
people_df
# Out:
#                 email first_name  last_name
# 0   suraj.w@email.com      Suraj       Wate
# 1   tapan.a@email.com      Tapan    Agrawal
# 2    leon.f@email.com       Leon  Fernandes
# 3  kushal.w@email.com     Kushal       Wate

# %%
people_df.rename(columns={'first_name': 'first', 'last_name': 'last'}, inplace=True)
people_df
# Out:
#                 email   first       last
# 0   suraj.w@email.com   Suraj       Wate
# 1   tapan.a@email.com   Tapan    Agrawal
# 2    leon.f@email.com    Leon  Fernandes
# 3  kushal.w@email.com  Kushal       Wate

# %% [markdown]
# ### How to update single value

# %%
people_df.loc[2]
# Out:
# email    leon.f@email.com
# first                Leon
# last            Fernandes
# Name: 2, dtype: object

# %%
people_df.loc[2] = ['thomas.a@email.com', 'Thomas', 'Anderson']
people_df
# Out:
#                 email   first      last
# 0   suraj.w@email.com   Suraj      Wate
# 1   tapan.a@email.com   Tapan   Agrawal
# 2  thomas.a@email.com  Thomas  Anderson
# 3  kushal.w@email.com  Kushal      Wate

# %%
people_df.loc[2, ['last', 'email']]
# Out:
# last               Anderson
# email    thomas.a@email.com
# Name: 2, dtype: object

# %%
people_df.loc[2, ['last', 'email']] = ['Fernandes', 'thomas.f@email.com']
people_df
# Out:
#                 email   first       last
# 0   suraj.w@email.com   Suraj       Wate
# 1   tapan.a@email.com   Tapan    Agrawal
# 2  thomas.f@email.com  Thomas  Fernandes
# 3  kushal.w@email.com  Kushal       Wate

# %%
people_df.loc[2, 'first'] = 'Leon'
people_df
# Out:
#                 email   first       last
# 0   suraj.w@email.com   Suraj       Wate
# 1   tapan.a@email.com   Tapan    Agrawal
# 2  thomas.f@email.com    Leon  Fernandes
# 3  kushal.w@email.com  Kushal       Wate

# %%
people_df.at[2, 'email'] = 'leon.f@email.com'
people_df
# Out:
#                 email   first       last
# 0   suraj.w@email.com   Suraj       Wate
# 1   tapan.a@email.com   Tapan    Agrawal
# 2    leon.f@email.com    Leon  Fernandes
# 3  kushal.w@email.com  Kushal       Wate

# %%
filt = (people_df['email'] == 'suraj.w@email.com')
people_df[filt]['last'] = 'Smith'
# Out:
# C:\Users\Suraj\AppData\Local\Temp\ipykernel_38612\3779162193.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   people_df[filt]['last'] = 'Smith'

# %%
filt = (people_df['email'] == 'suraj.w@email.com')
people_df.loc[filt, 'last'] = 'Smith'
people_df
# Out:
#                 email   first       last
# 0   suraj.w@email.com   Suraj      Smith
# 1   tapan.a@email.com   Tapan    Agrawal
# 2    leon.f@email.com    Leon  Fernandes
# 3  kushal.w@email.com  Kushal       Wate

# %% [markdown]
# ### Update multiple row of data

# %%
people_df['email'].str.upper()
# Out:
# 0     SURAJ.W@EMAIL.COM
# 1     TAPAN.A@EMAIL.COM
# 2      LEON.F@EMAIL.COM
# 3    KUSHAL.W@EMAIL.COM
# Name: email, dtype: object

# %%
people_df['email'] =  people_df['email'].str.lower()

# %% [markdown]
# There are four advanced method to update multiple row of data
#
# 1. apply
# 2. map
# 3. applymap
# 4. replace

# %% [markdown]
# #### Apply

# %%
people_df['email'].apply(len)
# Out:
# 0    17
# 1    17
# 2    16
# 3    18
# Name: email, dtype: int64

# %%
# Basic example to understand the concept

def update_email(email):
    return email.upper()

# %%
people_df['email'].apply(update_email)
# Out:
# 0     SURAJ.W@EMAIL.COM
# 1     TAPAN.A@EMAIL.COM
# 2      LEON.F@EMAIL.COM
# 3    KUSHAL.W@EMAIL.COM
# Name: email, dtype: object

# %%
people_df['email'] = people_df['email'].apply(update_email)
people_df
# Out:
#                 email   first       last
# 0   SURAJ.W@EMAIL.COM   Suraj      Smith
# 1   TAPAN.A@EMAIL.COM   Tapan    Agrawal
# 2    LEON.F@EMAIL.COM    Leon  Fernandes
# 3  KUSHAL.W@EMAIL.COM  Kushal       Wate

# %%
# Same example with lambda funtion

people_df['email'] = people_df['email'].apply(lambda x: x.lower())
people_df
# Out:
#                 email   first       last
# 0   suraj.w@email.com   Suraj      Smith
# 1   tapan.a@email.com   Tapan    Agrawal
# 2    leon.f@email.com    Leon  Fernandes
# 3  kushal.w@email.com  Kushal       Wate

# %%
# to check the number of the rows
people_df.apply(len)
# Out:
# email    4
# first    4
# last     4
# dtype: int64

# %%
# to check the number of the columns
people_df.apply(len, axis='columns')
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# dtype: int64

# %%
# To check the minimum value in the series

people_df.apply(pd.Series.min)
# Out:
# email    kushal.w@email.com
# first                Kushal
# last                Agrawal
# dtype: object

# %%
# Same example using lambda function

people_df.apply(lambda x: x.min())
# Out:
# email    kushal.w@email.com
# first                Kushal
# last                Agrawal
# dtype: object

# %% [markdown]
# #### Applymap

# %%
people_df.applymap(len)
# Out:
#    email  first  last
# 0     17      5     5
# 1     17      5     7
# 2     16      4     9
# 3     18      6     4

# %%
people_df.applymap(str.lower)
# Out:
#                 email   first       last
# 0   suraj.w@email.com   suraj      smith
# 1   tapan.a@email.com   tapan    agrawal
# 2    leon.f@email.com    leon  fernandes
# 3  kushal.w@email.com  kushal       wate

# %% [markdown]
# #### Map
#
# Map only works on the series

# %%
people_df
# Out:
#                 email   first       last
# 0   suraj.w@email.com   Suraj      Smith
# 1   tapan.a@email.com   Tapan    Agrawal
# 2    leon.f@email.com    Leon  Fernandes
# 3  kushal.w@email.com  Kushal       Wate

# %%
people_df['first'].map({'Suraj':'Agent', 'Tapan':'Thomas'})
# Out:
# 0     Agent
# 1    Thomas
# 2       NaN
# 3       NaN
# Name: first, dtype: object

# %% [markdown]
# #### Replace

# %%
people_df['first'].replace({'Suraj':'Agent', 'Tapan':'Thomas'})
# Out:
# 0     Agent
# 1    Thomas
# 2      Leon
# 3    Kushal
# Name: first, dtype: object

# %% [markdown]
# -------------------

# %%
# Rename the columns title

df.rename(columns={'ConvertedComp':'SalaryUSD'}, inplace=True)
df.head(2)
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# ...

# %%
df['SalaryUSD']
# Out:
# Respondent
# 1            NaN
# 2            NaN
# 3         8820.0
# 4        61000.0
# 5            NaN
#           ...
# 88377        NaN
# 88601        NaN
# 88802        NaN
# 88816        NaN
# 88863        NaN
# Name: SalaryUSD, Length: 88883, dtype: float64

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist'].map({'Yes':True, 'No':False})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 88377     True
# 88601    False
# 88802    False
# 88816    False
# 88863     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %%
df['Hobbyist'] = df['Hobbyist'].map({'Yes':True, 'No':False})

# %% [markdown]
# ## 6. Add/Remove Rows and Columns from DataFrames

# %% [markdown]
# ### Adding new column

# %%
people_df['full_name'] = people_df['first'] + ' ' + people_df['last']

# %%
people_df
# Out:
#                 email   first       last       full_name
# 0   suraj.w@email.com   Suraj      Smith     Suraj Smith
# 1   tapan.a@email.com   Tapan    Agrawal   Tapan Agrawal
# 2    leon.f@email.com    Leon  Fernandes  Leon Fernandes
# 3  kushal.w@email.com  Kushal       Wate     Kushal Wate

# %%
# Removing the columns

people_df.drop(columns=['first', 'last'], inplace=True)

# %%
people_df
# Out:
#                 email       full_name
# 0   suraj.w@email.com     Suraj Smith
# 1   tapan.a@email.com   Tapan Agrawal
# 2    leon.f@email.com  Leon Fernandes
# 3  kushal.w@email.com     Kushal Wate

# %%
# Splitting the column

people_df['full_name'].str.split(' ', expand = True)
# Out:
#         0          1
# 0   Suraj      Smith
# 1   Tapan    Agrawal
# 2    Leon  Fernandes
# 3  Kushal       Wate

# %%
people_df[['first', 'last']] = people_df['full_name'].str.split(' ', expand = True)

# %%
people_df
# Out:
#                 email       full_name   first       last
# 0   suraj.w@email.com     Suraj Smith   Suraj      Smith
# 1   tapan.a@email.com   Tapan Agrawal   Tapan    Agrawal
# 2    leon.f@email.com  Leon Fernandes    Leon  Fernandes
# 3  kushal.w@email.com     Kushal Wate  Kushal       Wate

# %% [markdown]
# ### Adding row

# %%
people_df.append({'first':'Tony'}, ignore_index=True)
# Out:
# C:\Users\Suraj\AppData\Local\Temp\ipykernel_38612\2735031197.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   people_df.append({'first':'Tony'}, ignore_index=True)
#                 email       full_name   first       last
# 0   suraj.w@email.com     Suraj Smith   Suraj      Smith
# 1   tapan.a@email.com   Tapan Agrawal   Tapan    Agrawal
# 2    leon.f@email.com  Leon Fernandes    Leon  Fernandes
# 3  kushal.w@email.com     Kushal Wate  Kushal       Wate
# 4                 NaN             NaN    Tony        NaN

# %%
pd.concat([people_df, pd.DataFrame.from_records([{'first':'Tony'}])])
# Out:
#                 email       full_name   first       last
# 0   suraj.w@email.com     Suraj Smith   Suraj      Smith
# 1   tapan.a@email.com   Tapan Agrawal   Tapan    Agrawal
# 2    leon.f@email.com  Leon Fernandes    Leon  Fernandes
# 3  kushal.w@email.com     Kushal Wate  Kushal       Wate
# 0                 NaN             NaN    Tony        NaN

# %%
people2 = {
    'first': ['Tony', 'Steve'],
    'last': ['Stark', 'Rogers'],
    'email': ['IronMan@avenge.com', 'Cap@avenge.com']
}
people_df2 = pd.DataFrame(people2)

# %%
people_df2
# Out:
#    first    last               email
# 0   Tony   Stark  IronMan@avenge.com
# 1  Steve  Rogers      Cap@avenge.com

# %%
pd.concat([people_df, people_df2])
# Out:
#                 email       full_name   first       last
# 0   suraj.w@email.com     Suraj Smith   Suraj      Smith
# 1   tapan.a@email.com   Tapan Agrawal   Tapan    Agrawal
# 2    leon.f@email.com  Leon Fernandes    Leon  Fernandes
# 3  kushal.w@email.com     Kushal Wate  Kushal       Wate
# 0  IronMan@avenge.com             NaN    Tony      Stark
# 1      Cap@avenge.com             NaN   Steve     Rogers

# %%
people_df
# Out:
#                 email       full_name   first       last
# 0   suraj.w@email.com     Suraj Smith   Suraj      Smith
# 1   tapan.a@email.com   Tapan Agrawal   Tapan    Agrawal
# 2    leon.f@email.com  Leon Fernandes    Leon  Fernandes
# 3  kushal.w@email.com     Kushal Wate  Kushal       Wate

# %% [markdown]
# Use ignore_index=True to ignore the existing index and reset the index.

# %%
people_df = pd.concat([people_df, people_df2], ignore_index=True)

# %%
people_df
# Out:
#                 email       full_name   first       last
# 0   suraj.w@email.com     Suraj Smith   Suraj      Smith
# 1   tapan.a@email.com   Tapan Agrawal   Tapan    Agrawal
# 2    leon.f@email.com  Leon Fernandes    Leon  Fernandes
# 3  kushal.w@email.com     Kushal Wate  Kushal       Wate
# 4  IronMan@avenge.com             NaN    Tony      Stark
# 5      Cap@avenge.com             NaN   Steve     Rogers

# %% [markdown]
# ### Remove rows

# %%
people_df.drop(index=1)
# Out:
#                 email       full_name   first       last
# 0   suraj.w@email.com     Suraj Smith   Suraj      Smith
# 2    leon.f@email.com  Leon Fernandes    Leon  Fernandes
# 3  kushal.w@email.com     Kushal Wate  Kushal       Wate
# 4  IronMan@avenge.com             NaN    Tony      Stark
# 5      Cap@avenge.com             NaN   Steve     Rogers

# %%
people_df.drop(index=people_df[people_df['last']=='Rogers'].index)
# Out:
#                 email       full_name   first       last
# 0   suraj.w@email.com     Suraj Smith   Suraj      Smith
# 1   tapan.a@email.com   Tapan Agrawal   Tapan    Agrawal
# 2    leon.f@email.com  Leon Fernandes    Leon  Fernandes
# 3  kushal.w@email.com     Kushal Wate  Kushal       Wate
# 4  IronMan@avenge.com             NaN    Tony      Stark

# %% [markdown]
# It's always better to break the code for better readability and understanding. So the above code can be breaked into two line.

# %%
filt = people_df['last']=='Rogers'
people_df.drop(index=people_df[filt].index)
# Out:
#                 email       full_name   first       last
# 0   suraj.w@email.com     Suraj Smith   Suraj      Smith
# 1   tapan.a@email.com   Tapan Agrawal   Tapan    Agrawal
# 2    leon.f@email.com  Leon Fernandes    Leon  Fernandes
# 3  kushal.w@email.com     Kushal Wate  Kushal       Wate
# 4  IronMan@avenge.com             NaN    Tony      Stark

# %% [markdown]
# ---------------

# %% [markdown]
# ## 7. Sorting Data

# %% [markdown]
# ## 8. Grouping and Aggregating - Analyzing and Exploring Your Data

# %% [markdown]
# ## 9. Cleaning Data - Casting Datatypes and Handling Missing Values

# %% [markdown]
# ## 10. Working with Dates and Time Series Data

# %% [markdown]
# ## 11. Reading/Writing Data to Different Sources
