# %% [markdown]
# # Pandas Tutorial

# %% [markdown]
# ## 1. Installation and Loading Data

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')

# %%
df.shape
# Out:
# (88883, 84)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88883 entries, 1 to 88863
# Data columns (total 84 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   MainBranch              88331 non-null  object
#  1   Hobbyist                88883 non-null  object
#  2   OpenSourcer             88883 non-null  object
#  3   OpenSource              86842 non-null  object
#  4   Employment              87181 non-null  object
#  5   Country                 88751 non-null  object
#  6   Student                 87014 non-null  object
#  7   EdLevel                 86390 non-null  object
#  8   UndergradMajor          75614 non-null  object
#  9   EduOther                84260 non-null  object
#  10  OrgSize                 71791 non-null  object
#  11  DevType                 81335 non-null  object
#  12  YearsCode               87938 non-null  object
#  13  Age1stCode              87634 non-null  object
# ...

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# ...

# %% [markdown]
# ## 2. Selecting Rows and Columns

# %%
people = {
    'first': ['Suraj', 'Tapan', 'Leon', 'Kushal'],
    'last' : ['Wate', 'Agrawal', 'Fernandes', 'Wate'],
    'email' : ['suraj.w@email.com', 'tapan.a@email.com', 'leon.f@email.com', 'kushal.w@email.com']
}

# %%
people_df = pd.DataFrame(people)

# %%
people_df
# Out:
#     first       last               email
# 0   Suraj       Wate   suraj.w@email.com
# 1   Tapan    Agrawal   tapan.a@email.com
# 2    Leon  Fernandes    leon.f@email.com
# 3  Kushal       Wate  kushal.w@email.com

# %% [markdown]
# ### Get column

# %%
# selecting column (which is a series)
people_df['email']
# Out:
# 0     suraj.w@email.com
# 1     tapan.a@email.com
# 2      leon.f@email.com
# 3    kushal.w@email.com
# Name: email, dtype: object

# %%
type(people_df['email'])
# Out:
# pandas.core.series.Series

# %%
# Same as above
people_df.email
# Out:
# 0     suraj.w@email.com
# 1     tapan.a@email.com
# 2      leon.f@email.com
# 3    kushal.w@email.com
# Name: email, dtype: object

# %%
people_df[['last', 'email']]
# Out:
#         last               email
# 0       Wate   suraj.w@email.com
# 1    Agrawal   tapan.a@email.com
# 2  Fernandes    leon.f@email.com
# 3       Wate  kushal.w@email.com

# %%
people_df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %% [markdown]
# ### To get the rows

# %%
people_df.iloc[0]
# Out:
# first                Suraj
# last                  Wate
# email    suraj.w@email.com
# Name: 0, dtype: object

# %%
people_df.iloc[[0, 1]]
# Out:
#    first     last              email
# 0  Suraj     Wate  suraj.w@email.com
# 1  Tapan  Agrawal  tapan.a@email.com

# %% [markdown]
# ### Get Specific rows and columns

# %%
people_df.iloc[[0, 1], 2]
# Out:
# 0    suraj.w@email.com
# 1    tapan.a@email.com
# Name: email, dtype: object

# %% [markdown]
# #### Using loc

# %%
people_df.loc[[0, 1], 'email']
# Out:
# 0    suraj.w@email.com
# 1    tapan.a@email.com
# Name: email, dtype: object

# %%
people_df.loc[[0, 2], ['email', 'last']]
# Out:
#                email       last
# 0  suraj.w@email.com       Wate
# 2   leon.f@email.com  Fernandes

# %%
df.shape
# Out:
# (88883, 84)

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df.loc[2, 'Hobbyist']
# Out:
# 'No'

# %%
df.loc[[4, 5, 8], 'Hobbyist']
# Out:
# Respondent
# 4     No
# 5    Yes
# 8    Yes
# Name: Hobbyist, dtype: object

# %%
# First three row

df.loc[1:3, 'Hobbyist':'Employment']
# Out:
#            Hobbyist              OpenSourcer  \
# Respondent
# 1               Yes                    Never
# 2                No  Less than once per year
# 3               Yes                    Never
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
#
#                                         Employment
# Respondent
# 1           Not employed, and not looking for work
# 2               Not employed, but looking for work
# 3                               Employed full-time

# %% [markdown]
# ## 3. Indexes - How to Set, Reset, and Use Indexes

# %%
people_df['email']
# Out:
# 0     suraj.w@email.com
# 1     tapan.a@email.com
# 2      leon.f@email.com
# 3    kushal.w@email.com
# Name: email, dtype: object

# %%
people_df.set_index('email')
# Out:
#                      first       last
# email
# suraj.w@email.com    Suraj       Wate
# tapan.a@email.com    Tapan    Agrawal
# leon.f@email.com      Leon  Fernandes
# kushal.w@email.com  Kushal       Wate

# %%
people_df
# Out:
#     first       last               email
# 0   Suraj       Wate   suraj.w@email.com
# 1   Tapan    Agrawal   tapan.a@email.com
# 2    Leon  Fernandes    leon.f@email.com
# 3  Kushal       Wate  kushal.w@email.com

# %%
people_df.set_index('email', inplace=True)

# %%
people_df
# Out:
#                      first       last
# email
# suraj.w@email.com    Suraj       Wate
# tapan.a@email.com    Tapan    Agrawal
# leon.f@email.com      Leon  Fernandes
# kushal.w@email.com  Kushal       Wate

# %%
people_df.index
# Out:
# Index(['suraj.w@email.com', 'tapan.a@email.com', 'leon.f@email.com',
#        'kushal.w@email.com'],
#       dtype='object', name='email')

# %%
people_df.loc['suraj.w@email.com']
# Out:
# first    Suraj
# last      Wate
# Name: suraj.w@email.com, dtype: object

# %% [markdown]
# ### Reset the index

# %%
people_df.reset_index(inplace=True)

# %%
people_df
# Out:
#                 email   first       last
# 0   suraj.w@email.com   Suraj       Wate
# 1   tapan.a@email.com   Tapan    Agrawal
# 2    leon.f@email.com    Leon  Fernandes
# 3  kushal.w@email.com  Kushal       Wate

# %% [markdown]
# ------------

# %%
schema_df.loc['Hobbyist']
# Out:
# QuestionText    Do you code as a hobby?
# Name: Hobbyist, dtype: object

# %%
schema_df.loc['MgrIdiot', 'QuestionText']
# Out:
# 'How confident are you that your manager knows what they’re doing?'

# %% [markdown]
# ### Sorting the dataframe by index

# %%
schema_df.sort_index(inplace=True)

# %%
schema_df.sort_index(ascending=False)
# Out:
#                                                              QuestionText
# Column
# YearsCodePro            How many years have you coded professionally (...
# YearsCode               Including any education, how many years have y...
# WorkWeekHrs              On average, how many hours per week do you work?
# WorkRemote                                How often do you work remotely?
# WorkPlan                          How structured or planned is your work?
# WorkLoc                                   Where would you prefer to work?
# WorkChallenge           Of these options, what are your greatest chall...
# WelcomeChange           Compared to last year, how welcome do you feel...
# WebFrameWorkedWith      Which of the following web frameworks have you...
# WebFrameDesireNextYear  Which of the following web frameworks have you...
# UnitTests               Does your company regularly employ unit tests ...
# UndergradMajor          What was your main or most important field of ...
# ...

# %% [markdown]
# ## 4. Filtering - Using conditionals to filter rows and columns

# %%
people_df['last'] == 'Agrawal'
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# Name: last, dtype: bool

# %%
filt = (people_df['last'] == 'Agrawal')

# %%
people_df[filt]
# Out:
#                email  first     last
# 1  tapan.a@email.com  Tapan  Agrawal

# %%
people_df[people_df['last'] == 'Agrawal']
# Out:
#                email  first     last
# 1  tapan.a@email.com  Tapan  Agrawal

# %%
people_df.loc[filt]
# Out:
#                email  first     last
# 1  tapan.a@email.com  Tapan  Agrawal

# %%
people_df.loc[filt, 'email']
# Out:
# 1    tapan.a@email.com
# Name: email, dtype: object

# %% [markdown]
# ### AND and OR operators

# %%
filt = (people_df['last'] == 'Wate') & (people_df['first'] == 'Kushal')

# %%
people_df.loc[filt, 'email']
# Out:
# 3    kushal.w@email.com
# Name: email, dtype: object

# %%
# NOT operator

people_df.loc[~filt, 'email']
# Out:
# 0    suraj.w@email.com
# 1    tapan.a@email.com
# 2     leon.f@email.com
# Name: email, dtype: object

# %% [markdown]
# ----------

# %%
high_salary = (df['ConvertedComp'] > 70000)

# %%
df.loc[high_salary, ['Country', 'LanguageWorkedWith', 'ConvertedComp']]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 6                   Canada                                         Java;R;SQL
# 9              New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 13           United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 16          United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 22           United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...                    ...                                                ...
# 88876        United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88877        United States  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88878        United States               HTML/CSS;JavaScript;Scala;TypeScript
# 88879              Finland                   Bash/Shell/PowerShell;C++;Python
# 88882          Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
# ...

# %%
countries  = ['United States', 'India', 'United Kingdon', 'Germany', 'Canada']
filt = df['Country'].isin(countries)

# %%
df.loc[filt, 'Country']
# Out:
# Respondent
# 4        United States
# 6               Canada
# 8                India
# 10               India
# 12              Canada
#              ...
# 85182           Canada
# 85642    United States
# 86012            India
# 88282    United States
# 88377           Canada
# Name: Country, Length: 39271, dtype: object

# %% [markdown]
# ### Filter Strings

# %%
df['LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 3                                                 HTML/CSS
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#                                ...
# 88377                        HTML/CSS;JavaScript;Other(s):
# 88601                                                  NaN
# 88802                                                  NaN
# 88816                                                  NaN
# 88863    Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# Name: LanguageWorkedWith, Length: 88883, dtype: object

# %%
filt = df['LanguageWorkedWith'].str.contains('Python', na=False)

# %%
df.loc[filt, 'LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 84539    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 85738      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 86566      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 87739             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88212                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %% [markdown]
# ------------

# %% [markdown]
# ## 5. Updating Rows and Columns - Modifying Data Within DataFrames

# %%
people_df
# Out:
#                 email   first       last
# 0   suraj.w@email.com   Suraj       Wate
# 1   tapan.a@email.com   Tapan    Agrawal
# 2    leon.f@email.com    Leon  Fernandes
# 3  kushal.w@email.com  Kushal       Wate

# %%
people_df.columns
# Out:
# Index(['email', 'first', 'last'], dtype='object')

# %%
people_df.columns = ['email', 'first_name', 'last_name']

# %%
people_df
# Out:
#                 email first_name  last_name
# 0   suraj.w@email.com      Suraj       Wate
# 1   tapan.a@email.com      Tapan    Agrawal
# 2    leon.f@email.com       Leon  Fernandes
# 3  kushal.w@email.com     Kushal       Wate

# %%
people_df.columns = [x.upper() for x in people_df.columns]
people_df
# Out:
#                 EMAIL FIRST_NAME  LAST_NAME
# 0   suraj.w@email.com      Suraj       Wate
# 1   tapan.a@email.com      Tapan    Agrawal
# 2    leon.f@email.com       Leon  Fernandes
# 3  kushal.w@email.com     Kushal       Wate

# %%
people_df.columns = people_df.columns.str.replace('_', ' ')
people_df
# Out:
#                 EMAIL FIRST NAME  LAST NAME
# 0   suraj.w@email.com      Suraj       Wate
# 1   tapan.a@email.com      Tapan    Agrawal
# 2    leon.f@email.com       Leon  Fernandes
# 3  kushal.w@email.com     Kushal       Wate

# %%
people_df.columns = [x.lower() for x in people_df.columns]
people_df.columns = people_df.columns.str.replace(' ', '_')
people_df
# Out:
#                 email first_name  last_name
# 0   suraj.w@email.com      Suraj       Wate
# 1   tapan.a@email.com      Tapan    Agrawal
# 2    leon.f@email.com       Leon  Fernandes
# 3  kushal.w@email.com     Kushal       Wate

# %%
people_df.rename(columns={'first_name': 'first', 'last_name': 'last'}, inplace=True)
people_df
# Out:
#                 email   first       last
# 0   suraj.w@email.com   Suraj       Wate
# 1   tapan.a@email.com   Tapan    Agrawal
# 2    leon.f@email.com    Leon  Fernandes
# 3  kushal.w@email.com  Kushal       Wate

# %% [markdown]
# ### How to update single value

# %%
people_df.loc[2]
# Out:
# email    leon.f@email.com
# first                Leon
# last            Fernandes
# Name: 2, dtype: object

# %%
people_df.loc[2] = ['thomas.a@email.com', 'Thomas', 'Anderson']
people_df
# Out:
#                 email   first      last
# 0   suraj.w@email.com   Suraj      Wate
# 1   tapan.a@email.com   Tapan   Agrawal
# 2  thomas.a@email.com  Thomas  Anderson
# 3  kushal.w@email.com  Kushal      Wate

# %%
people_df.loc[2, ['last', 'email']]
# Out:
# last               Anderson
# email    thomas.a@email.com
# Name: 2, dtype: object

# %%
people_df.loc[2, ['last', 'email']] = ['Fernandes', 'thomas.f@email.com']
people_df
# Out:
#                 email   first       last
# 0   suraj.w@email.com   Suraj       Wate
# 1   tapan.a@email.com   Tapan    Agrawal
# 2  thomas.f@email.com  Thomas  Fernandes
# 3  kushal.w@email.com  Kushal       Wate

# %%
people_df.loc[2, 'first'] = 'Leon'
people_df
# Out:
#                 email   first       last
# 0   suraj.w@email.com   Suraj       Wate
# 1   tapan.a@email.com   Tapan    Agrawal
# 2  thomas.f@email.com    Leon  Fernandes
# 3  kushal.w@email.com  Kushal       Wate

# %%
people_df.at[2, 'email'] = 'leon.f@email.com'
people_df
# Out:
#                 email   first       last
# 0   suraj.w@email.com   Suraj       Wate
# 1   tapan.a@email.com   Tapan    Agrawal
# 2    leon.f@email.com    Leon  Fernandes
# 3  kushal.w@email.com  Kushal       Wate

# %%
filt = (people_df['email'] == 'suraj.w@email.com')
people_df[filt]['last'] = 'Smith'
# Out:
# C:\Users\Suraj\AppData\Local\Temp\ipykernel_9040\3779162193.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   people_df[filt]['last'] = 'Smith'

# %%
filt = (people_df['email'] == 'suraj.w@email.com')
people_df.loc[filt, 'last'] = 'Smith'
people_df
# Out:
#                 email   first       last
# 0   suraj.w@email.com   Suraj      Smith
# 1   tapan.a@email.com   Tapan    Agrawal
# 2    leon.f@email.com    Leon  Fernandes
# 3  kushal.w@email.com  Kushal       Wate

# %% [markdown]
# ### Update multiple row of data

# %%
people_df['email'].str.upper()
# Out:
# 0     SURAJ.W@EMAIL.COM
# 1     TAPAN.A@EMAIL.COM
# 2      LEON.F@EMAIL.COM
# 3    KUSHAL.W@EMAIL.COM
# Name: email, dtype: object

# %%
people_df['email'] =  people_df['email'].str.lower()

# %% [markdown]
# There are four advanced method to update multiple row of data
#
# 1. apply
# 2. map
# 3. applymap
# 4. replace

# %% [markdown]
# #### Apply

# %%
people_df['email'].apply(len)
# Out:
# 0    17
# 1    17
# 2    16
# 3    18
# Name: email, dtype: int64

# %%
# Basic example to understand the concept

def update_email(email):
    return email.upper()

# %%
people_df['email'].apply(update_email)
# Out:
# 0     SURAJ.W@EMAIL.COM
# 1     TAPAN.A@EMAIL.COM
# 2      LEON.F@EMAIL.COM
# 3    KUSHAL.W@EMAIL.COM
# Name: email, dtype: object

# %%
people_df['email'] = people_df['email'].apply(update_email)
people_df
# Out:
#                 email   first       last
# 0   SURAJ.W@EMAIL.COM   Suraj      Smith
# 1   TAPAN.A@EMAIL.COM   Tapan    Agrawal
# 2    LEON.F@EMAIL.COM    Leon  Fernandes
# 3  KUSHAL.W@EMAIL.COM  Kushal       Wate

# %%
# Same example with lambda funtion

people_df['email'] = people_df['email'].apply(lambda x: x.lower())
people_df
# Out:
#                 email   first       last
# 0   suraj.w@email.com   Suraj      Smith
# 1   tapan.a@email.com   Tapan    Agrawal
# 2    leon.f@email.com    Leon  Fernandes
# 3  kushal.w@email.com  Kushal       Wate

# %%
# to check the number of the rows
people_df.apply(len)
# Out:
# email    4
# first    4
# last     4
# dtype: int64

# %%
# to check the number of the columns
people_df.apply(len, axis='columns')
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# dtype: int64

# %%
# To check the minimum value in the series

people_df.apply(pd.Series.min)
# Out:
# email    kushal.w@email.com
# first                Kushal
# last                Agrawal
# dtype: object

# %%
# Same example using lambda function

people_df.apply(lambda x: x.min())
# Out:
# email    kushal.w@email.com
# first                Kushal
# last                Agrawal
# dtype: object

# %% [markdown]
# #### Applymap

# %%
people_df.applymap(len)
# Out:
#    email  first  last
# 0     17      5     5
# 1     17      5     7
# 2     16      4     9
# 3     18      6     4

# %%
people_df.applymap(str.lower)
# Out:
#                 email   first       last
# 0   suraj.w@email.com   suraj      smith
# 1   tapan.a@email.com   tapan    agrawal
# 2    leon.f@email.com    leon  fernandes
# 3  kushal.w@email.com  kushal       wate

# %% [markdown]
# #### Map
#
# Map only works on the series

# %%
people_df
# Out:
#                 email   first       last
# 0   suraj.w@email.com   Suraj      Smith
# 1   tapan.a@email.com   Tapan    Agrawal
# 2    leon.f@email.com    Leon  Fernandes
# 3  kushal.w@email.com  Kushal       Wate

# %%
people_df['first'].map({'Suraj':'Agent', 'Tapan':'Thomas'})
# Out:
# 0     Agent
# 1    Thomas
# 2       NaN
# 3       NaN
# Name: first, dtype: object

# %% [markdown]
# #### Replace

# %%
people_df['first'].replace({'Suraj':'Agent', 'Tapan':'Thomas'})
# Out:
# 0     Agent
# 1    Thomas
# 2      Leon
# 3    Kushal
# Name: first, dtype: object

# %% [markdown]
# -------------------

# %%
# Rename the columns title

df.rename(columns={'ConvertedComp':'SalaryUSD'}, inplace=True)
df.head(2)
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# ...

# %%
df['SalaryUSD']
# Out:
# Respondent
# 1            NaN
# 2            NaN
# 3         8820.0
# 4        61000.0
# 5            NaN
#           ...
# 88377        NaN
# 88601        NaN
# 88802        NaN
# 88816        NaN
# 88863        NaN
# Name: SalaryUSD, Length: 88883, dtype: float64

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist'].map({'Yes':True, 'No':False})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 88377     True
# 88601    False
# 88802    False
# 88816    False
# 88863     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %%
df['Hobbyist'] = df['Hobbyist'].map({'Yes':True, 'No':False})

# %% [markdown]
# ## 6. Add/Remove Rows and Columns from DataFrames

# %% [markdown]
# ### Adding new column

# %%
people_df['full_name'] = people_df['first'] + ' ' + people_df['last']

# %%
people_df
# Out:
#                 email   first       last       full_name
# 0   suraj.w@email.com   Suraj      Smith     Suraj Smith
# 1   tapan.a@email.com   Tapan    Agrawal   Tapan Agrawal
# 2    leon.f@email.com    Leon  Fernandes  Leon Fernandes
# 3  kushal.w@email.com  Kushal       Wate     Kushal Wate

# %%
# Removing the columns

people_df.drop(columns=['first', 'last'], inplace=True)

# %%
people_df
# Out:
#                 email       full_name
# 0   suraj.w@email.com     Suraj Smith
# 1   tapan.a@email.com   Tapan Agrawal
# 2    leon.f@email.com  Leon Fernandes
# 3  kushal.w@email.com     Kushal Wate

# %%
# Splitting the column

people_df['full_name'].str.split(' ', expand = True)
# Out:
#         0          1
# 0   Suraj      Smith
# 1   Tapan    Agrawal
# 2    Leon  Fernandes
# 3  Kushal       Wate

# %%
people_df[['first', 'last']] = people_df['full_name'].str.split(' ', expand = True)

# %%
people_df
# Out:
#                 email       full_name   first       last
# 0   suraj.w@email.com     Suraj Smith   Suraj      Smith
# 1   tapan.a@email.com   Tapan Agrawal   Tapan    Agrawal
# 2    leon.f@email.com  Leon Fernandes    Leon  Fernandes
# 3  kushal.w@email.com     Kushal Wate  Kushal       Wate

# %% [markdown]
# ### Adding row

# %%
people_df.append({'first':'Tony'}, ignore_index=True)
# Out:
# C:\Users\Suraj\AppData\Local\Temp\ipykernel_9040\2735031197.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   people_df.append({'first':'Tony'}, ignore_index=True)
#                 email       full_name   first       last
# 0   suraj.w@email.com     Suraj Smith   Suraj      Smith
# 1   tapan.a@email.com   Tapan Agrawal   Tapan    Agrawal
# 2    leon.f@email.com  Leon Fernandes    Leon  Fernandes
# 3  kushal.w@email.com     Kushal Wate  Kushal       Wate
# 4                 NaN             NaN    Tony        NaN

# %%
pd.concat([people_df, pd.DataFrame.from_records([{'first':'Tony'}])])
# Out:
#                 email       full_name   first       last
# 0   suraj.w@email.com     Suraj Smith   Suraj      Smith
# 1   tapan.a@email.com   Tapan Agrawal   Tapan    Agrawal
# 2    leon.f@email.com  Leon Fernandes    Leon  Fernandes
# 3  kushal.w@email.com     Kushal Wate  Kushal       Wate
# 0                 NaN             NaN    Tony        NaN

# %%
people2 = {
    'first': ['Tony', 'Steve'],
    'last': ['Stark', 'Rogers'],
    'email': ['IronMan@avenge.com', 'Cap@avenge.com']
}
people_df2 = pd.DataFrame(people2)

# %%
people_df2
# Out:
#    first    last               email
# 0   Tony   Stark  IronMan@avenge.com
# 1  Steve  Rogers      Cap@avenge.com

# %%
pd.concat([people_df, people_df2])
# Out:
#                 email       full_name   first       last
# 0   suraj.w@email.com     Suraj Smith   Suraj      Smith
# 1   tapan.a@email.com   Tapan Agrawal   Tapan    Agrawal
# 2    leon.f@email.com  Leon Fernandes    Leon  Fernandes
# 3  kushal.w@email.com     Kushal Wate  Kushal       Wate
# 0  IronMan@avenge.com             NaN    Tony      Stark
# 1      Cap@avenge.com             NaN   Steve     Rogers

# %%
people_df
# Out:
#                 email       full_name   first       last
# 0   suraj.w@email.com     Suraj Smith   Suraj      Smith
# 1   tapan.a@email.com   Tapan Agrawal   Tapan    Agrawal
# 2    leon.f@email.com  Leon Fernandes    Leon  Fernandes
# 3  kushal.w@email.com     Kushal Wate  Kushal       Wate

# %% [markdown]
# Use ignore_index=True to ignore the existing index and reset the index.

# %%
people_df = pd.concat([people_df, people_df2], ignore_index=True)

# %%
people_df
# Out:
#                 email       full_name   first       last
# 0   suraj.w@email.com     Suraj Smith   Suraj      Smith
# 1   tapan.a@email.com   Tapan Agrawal   Tapan    Agrawal
# 2    leon.f@email.com  Leon Fernandes    Leon  Fernandes
# 3  kushal.w@email.com     Kushal Wate  Kushal       Wate
# 4  IronMan@avenge.com             NaN    Tony      Stark
# 5      Cap@avenge.com             NaN   Steve     Rogers

# %% [markdown]
# ### Remove rows

# %%
people_df.drop(index=1)
# Out:
#                 email       full_name   first       last
# 0   suraj.w@email.com     Suraj Smith   Suraj      Smith
# 2    leon.f@email.com  Leon Fernandes    Leon  Fernandes
# 3  kushal.w@email.com     Kushal Wate  Kushal       Wate
# 4  IronMan@avenge.com             NaN    Tony      Stark
# 5      Cap@avenge.com             NaN   Steve     Rogers

# %%
people_df.drop(index=people_df[people_df['last']=='Rogers'].index)
# Out:
#                 email       full_name   first       last
# 0   suraj.w@email.com     Suraj Smith   Suraj      Smith
# 1   tapan.a@email.com   Tapan Agrawal   Tapan    Agrawal
# 2    leon.f@email.com  Leon Fernandes    Leon  Fernandes
# 3  kushal.w@email.com     Kushal Wate  Kushal       Wate
# 4  IronMan@avenge.com             NaN    Tony      Stark

# %% [markdown]
# It's always better to break the code for better readability and understanding. So the above code can be breaked into two line.

# %%
filt = people_df['last']=='Rogers'
people_df.drop(index=people_df[filt].index)
# Out:
#                 email       full_name   first       last
# 0   suraj.w@email.com     Suraj Smith   Suraj      Smith
# 1   tapan.a@email.com   Tapan Agrawal   Tapan    Agrawal
# 2    leon.f@email.com  Leon Fernandes    Leon  Fernandes
# 3  kushal.w@email.com     Kushal Wate  Kushal       Wate
# 4  IronMan@avenge.com             NaN    Tony      Stark

# %% [markdown]
# ---------------

# %% [markdown]
# ## 7. Sorting Data

# %%
people_df.sort_values(by='last')
# Out:
#                 email       full_name   first       last
# 1   tapan.a@email.com   Tapan Agrawal   Tapan    Agrawal
# 2    leon.f@email.com  Leon Fernandes    Leon  Fernandes
# 5      Cap@avenge.com             NaN   Steve     Rogers
# 0   suraj.w@email.com     Suraj Smith   Suraj      Smith
# 4  IronMan@avenge.com             NaN    Tony      Stark
# 3  kushal.w@email.com     Kushal Wate  Kushal       Wate

# %%
people_df.sort_values(by='last', ascending=False)
# Out:
#                 email       full_name   first       last
# 3  kushal.w@email.com     Kushal Wate  Kushal       Wate
# 4  IronMan@avenge.com             NaN    Tony      Stark
# 0   suraj.w@email.com     Suraj Smith   Suraj      Smith
# 5      Cap@avenge.com             NaN   Steve     Rogers
# 2    leon.f@email.com  Leon Fernandes    Leon  Fernandes
# 1   tapan.a@email.com   Tapan Agrawal   Tapan    Agrawal

# %%
people_df.loc[0, 'last'] = 'Wate'
people_df
# Out:
#                 email       full_name   first       last
# 0   suraj.w@email.com     Suraj Smith   Suraj       Wate
# 1   tapan.a@email.com   Tapan Agrawal   Tapan    Agrawal
# 2    leon.f@email.com  Leon Fernandes    Leon  Fernandes
# 3  kushal.w@email.com     Kushal Wate  Kushal       Wate
# 4  IronMan@avenge.com             NaN    Tony      Stark
# 5      Cap@avenge.com             NaN   Steve     Rogers

# %%
people_df.sort_values(by=['last', 'first'], ascending=False)
# Out:
#                 email       full_name   first       last
# 0   suraj.w@email.com     Suraj Smith   Suraj       Wate
# 3  kushal.w@email.com     Kushal Wate  Kushal       Wate
# 4  IronMan@avenge.com             NaN    Tony      Stark
# 5      Cap@avenge.com             NaN   Steve     Rogers
# 2    leon.f@email.com  Leon Fernandes    Leon  Fernandes
# 1   tapan.a@email.com   Tapan Agrawal   Tapan    Agrawal

# %%
people_df.sort_values(by=['last', 'first'], ascending=[False, True])
# Out:
#                 email       full_name   first       last
# 3  kushal.w@email.com     Kushal Wate  Kushal       Wate
# 0   suraj.w@email.com     Suraj Smith   Suraj       Wate
# 4  IronMan@avenge.com             NaN    Tony      Stark
# 5      Cap@avenge.com             NaN   Steve     Rogers
# 2    leon.f@email.com  Leon Fernandes    Leon  Fernandes
# 1   tapan.a@email.com   Tapan Agrawal   Tapan    Agrawal

# %%
people_df.sort_values(by=['last', 'first'], ascending=[False, True], inplace=True)

# %%
people_df
# Out:
#                 email       full_name   first       last
# 3  kushal.w@email.com     Kushal Wate  Kushal       Wate
# 0   suraj.w@email.com     Suraj Smith   Suraj       Wate
# 4  IronMan@avenge.com             NaN    Tony      Stark
# 5      Cap@avenge.com             NaN   Steve     Rogers
# 2    leon.f@email.com  Leon Fernandes    Leon  Fernandes
# 1   tapan.a@email.com   Tapan Agrawal   Tapan    Agrawal

# %% [markdown]
# To reset the index value use sort_index()

# %%
people_df.sort_index()
# Out:
#                 email       full_name   first       last
# 0   suraj.w@email.com     Suraj Smith   Suraj       Wate
# 1   tapan.a@email.com   Tapan Agrawal   Tapan    Agrawal
# 2    leon.f@email.com  Leon Fernandes    Leon  Fernandes
# 3  kushal.w@email.com     Kushal Wate  Kushal       Wate
# 4  IronMan@avenge.com             NaN    Tony      Stark
# 5      Cap@avenge.com             NaN   Steve     Rogers

# %% [markdown]
# ### Sort single column
#
# If you want to single columns, then single series can also be sorted.

# %%
people_df['last'].sort_values()
# Out:
# 1      Agrawal
# 2    Fernandes
# 5       Rogers
# 4        Stark
# 3         Wate
# 0         Wate
# Name: last, dtype: object

# %% [markdown]
# --------------

# %%
df.sort_values(by='Country', inplace=True)
df['Country'].head(50)
# Out:
# Respondent
# 39258    Afghanistan
# 63129    Afghanistan
# 85715    Afghanistan
# 50767    Afghanistan
# 2782     Afghanistan
# 63019    Afghanistan
# 6417     Afghanistan
# 40000    Afghanistan
# 88731    Afghanistan
# 48436    Afghanistan
# 10746    Afghanistan
# 62525    Afghanistan
# 49702    Afghanistan
# 33178    Afghanistan
# 60946    Afghanistan
# 86362    Afghanistan
# 88582    Afghanistan
# 28638    Afghanistan
# 722      Afghanistan
# 26340    Afghanistan
# 86932    Afghanistan
# 85825    Afghanistan
# 7085     Afghanistan
# 7353     Afghanistan
# 87091    Afghanistan
# 58760    Afghanistan
# 74386    Afghanistan
# 29045    Afghanistan
# 51859    Afghanistan
# 45854    Afghanistan
# 47110    Afghanistan
# 44403    Afghanistan
# 22450    Afghanistan
# 8149     Afghanistan
# 80926    Afghanistan
# 59560    Afghanistan
# 60569    Afghanistan
# 37802    Afghanistan
# 29736    Afghanistan
# 43106    Afghanistan
# 12310    Afghanistan
# 58450    Afghanistan
# ...

# %%
df[['Country', 'SalaryUSD']].head(50)
# Out:
#                 Country  SalaryUSD
# Respondent
# 39258       Afghanistan    19152.0
# 63129       Afghanistan  1000000.0
# 85715       Afghanistan        NaN
# 50767       Afghanistan        NaN
# 2782        Afghanistan        NaN
# 63019       Afghanistan        NaN
# 6417        Afghanistan        NaN
# 40000       Afghanistan        NaN
# 88731       Afghanistan        NaN
# 48436       Afghanistan     4464.0
# 10746       Afghanistan     3996.0
# 62525       Afghanistan        NaN
# 49702       Afghanistan        NaN
# 33178       Afghanistan        NaN
# 60946       Afghanistan        NaN
# 86362       Afghanistan        NaN
# 88582       Afghanistan        NaN
# 28638       Afghanistan        0.0
# 722         Afghanistan        0.0
# 26340       Afghanistan        NaN
# 86932       Afghanistan        NaN
# 85825       Afghanistan        NaN
# 7085        Afghanistan    14364.0
# 7353        Afghanistan        NaN
# 87091       Afghanistan        NaN
# ...

# %%
df.sort_values(by=['Country', 'SalaryUSD'], ascending=[True, False], inplace=True)

# %%
df[['Country', 'SalaryUSD']].head(50)
# Out:
#                 Country  SalaryUSD
# Respondent
# 63129       Afghanistan  1000000.0
# 50499       Afghanistan   153216.0
# 39258       Afghanistan    19152.0
# 58450       Afghanistan    17556.0
# 7085        Afghanistan    14364.0
# 22450       Afghanistan     7980.0
# 48436       Afghanistan     4464.0
# 10746       Afghanistan     3996.0
# 8149        Afghanistan     1596.0
# 29736       Afghanistan     1116.0
# 28638       Afghanistan        0.0
# 722         Afghanistan        0.0
# 85715       Afghanistan        NaN
# 50767       Afghanistan        NaN
# 2782        Afghanistan        NaN
# 63019       Afghanistan        NaN
# 6417        Afghanistan        NaN
# 40000       Afghanistan        NaN
# 88731       Afghanistan        NaN
# 62525       Afghanistan        NaN
# 49702       Afghanistan        NaN
# 33178       Afghanistan        NaN
# 60946       Afghanistan        NaN
# 86362       Afghanistan        NaN
# 88582       Afghanistan        NaN
# ...

# %% [markdown]
# ### Get highest and lowest values

# %%
df['SalaryUSD'].nlargest(10)
# Out:
# Respondent
# 25983    2000000.0
# 87896    2000000.0
# 22013    2000000.0
# 28243    2000000.0
# 72732    2000000.0
# 78151    2000000.0
# 80200    2000000.0
# 52132    2000000.0
# 75561    2000000.0
# 32250    2000000.0
# Name: SalaryUSD, dtype: float64

# %%
df.nlargest(10, 'SalaryUSD')
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 25983                          I am a developer by profession      True
# 87896                          I am a developer by profession      True
# 22013                          I am a developer by profession      True
# 28243                          I am a developer by profession      True
# 72732       I am not primarily a developer, but I write co...     False
# 78151                          I am a developer by profession      True
# 80200                          I am a developer by profession      True
# 52132                          I am a developer by profession      True
# 75561                          I am a developer by profession      True
# 32250                          I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# 25983                                 Less than once per year
# ...

# %%
df['SalaryUSD'].nsmallest(10)
# Out:
# Respondent
# 28638    0.0
# 722      0.0
# 13825    0.0
# 40913    0.0
# 30630    0.0
# 69049    0.0
# 19340    0.0
# 16214    0.0
# 29355    0.0
# 1685     0.0
# Name: SalaryUSD, dtype: float64

# %% [markdown]
# ---------------

# %% [markdown]
# ## 8. Grouping and Aggregating - Analyzing and Exploring Your Data

# %% [markdown]
# ### Basic Aggregation

# %%
df['SalaryUSD'].head()
# Out:
# Respondent
# 63129    1000000.0
# 50499     153216.0
# 39258      19152.0
# 58450      17556.0
# 7085       14364.0
# Name: SalaryUSD, dtype: float64

# %%
df['SalaryUSD'].median()
# Out:
# 57287.0

# %%
df.median()
# Out:
# C:\Users\Suraj\AppData\Local\Temp\ipykernel_9040\530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# Hobbyist           1.0
# CompTotal      62000.0
# SalaryUSD      57287.0
# WorkWeekHrs       40.0
# CodeRevHrs         4.0
# Age               29.0
# dtype: float64

# %% [markdown]
# To get a broad overview of different stats of the dataframe

# %%
df.describe()
# Out:
#           CompTotal     SalaryUSD   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04  5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11  1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13  2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00  0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04  2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04  5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05  1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16  2.000000e+06   4850.000000     99.000000     99.000000

# %%
df['SalaryUSD'].count()
# Out:
# 55823

# %%
df['Hobbyist']
# Out:
# Respondent
# 63129     True
# 50499     True
# 39258     True
# 58450     True
# 7085      True
#          ...
# 88062    False
# 88076    False
# 88601    False
# 88802    False
# 88816    False
# Name: Hobbyist, Length: 88883, dtype: bool

# %% [markdown]
# ### Count the Values of the column

# %%
df['Hobbyist'].value_counts()
# Out:
# True     71257
# False    17626
# Name: Hobbyist, dtype: int64

# %%
schema_df.loc['SocialMedia']
# Out:
# QuestionText    What social media site do you use the most?
# Name: SocialMedia, dtype: object

# %%
df['SocialMedia'].value_counts()
# Out:
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: SocialMedia, dtype: int64

# %% [markdown]
# Getting the values in percentage

# %%
df['SocialMedia'].value_counts(normalize=True)
# Out:
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: SocialMedia, dtype: float64

# %% [markdown]
# ### Grouping of the data
#
# A groupby operation involves some combination of splitting the object, applying a function, and combining the results. This can be used to group large amounts of data and compute operations on these groups.

# %%
df['Country'].value_counts()
# Out:
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# North Korea                             1
# Niger                                   1
# Saint Vincent and the Grenadines        1
# Chad                                    1
# Brunei Darussalam                       1
# Name: Country, Length: 179, dtype: int64

# %%
df.groupby(['Country'])

# %% [markdown]
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x0000017ECA58B6A0>
#
# This object contains bunch of groups.

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('United States')
# Out:
#                                 MainBranch  Hobbyist  \
# Respondent
# 2940        I am a developer by profession      True
# 3133        I am a developer by profession      True
# 78960       I am a developer by profession      True
# 3120        I am a developer by profession      True
# 78853       I am a developer by profession     False
# ...                                    ...       ...
# 32801       I am a developer by profession     False
# 32811       I am a developer by profession     False
# 32886       I am a developer by profession     False
# 68604       I am a developer by profession      True
# 33792       I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# 2940                                                    Never
# 3133                                                    Never
# 78960                                 Less than once per year
# ...

# %%
filt = df['Country'] == 'United States'
df.loc[filt]
# Out:
#                                 MainBranch  Hobbyist  \
# Respondent
# 2940        I am a developer by profession      True
# 3133        I am a developer by profession      True
# 78960       I am a developer by profession      True
# 3120        I am a developer by profession      True
# 78853       I am a developer by profession     False
# ...                                    ...       ...
# 32801       I am a developer by profession     False
# 32811       I am a developer by profession     False
# 32886       I am a developer by profession     False
# 68604       I am a developer by profession      True
# 33792       I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# 2940                                                    Never
# 3133                                                    Never
# 78960                                 Less than once per year
# ...

# %%
df.loc[filt]['SocialMedia'].value_counts()
# Out:
# Reddit                      5700
# Twitter                     3468
# Facebook                    2844
# YouTube                     2463
# I don't use social media    1851
# Instagram                   1652
# LinkedIn                    1020
# WhatsApp                     609
# Snapchat                     326
# WeChat 微信                     93
# VK ВКонта́кте                  9
# Weibo 新浪微博                     8
# Hello                          2
# Youku Tudou 优酷                 1
# Name: SocialMedia, dtype: int64

# %%
country_grp['SocialMedia'].value_counts()
# Out:
# Country      SocialMedia
# Afghanistan  Facebook                    15
#              YouTube                      9
#              I don't use social media     6
#              WhatsApp                     4
#              Instagram                    1
#                                          ..
# Zimbabwe     Facebook                     3
#              YouTube                      3
#              Instagram                    2
#              LinkedIn                     2
#              Reddit                       1
# Name: SocialMedia, Length: 1220, dtype: int64

# %% [markdown]
# From the above groups if we want to get value from any particular country.

# %%
country_grp['SocialMedia'].value_counts().loc['India']
# Out:
# SocialMedia
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: SocialMedia, dtype: int64

# %%
country_grp['SocialMedia'].value_counts(normalize=True).loc['India']
# Out:
# SocialMedia
# WhatsApp                    0.342379
# YouTube                     0.208405
# LinkedIn                    0.109355
# Facebook                    0.096301
# Instagram                   0.094126
# Twitter                     0.062063
# Reddit                      0.054162
# I don't use social media    0.028627
# Snapchat                    0.002634
# Hello                       0.000573
# WeChat 微信                   0.000573
# VK ВКонта́кте               0.000458
# Youku Tudou 优酷              0.000229
# Weibo 新浪微博                  0.000115
# Name: SocialMedia, dtype: float64

# %%
country_grp['SalaryUSD'].median()
# Out:
# Country
# Afghanistan                               6222.0
# Albania                                  10818.0
# Algeria                                   7878.0
# Andorra                                 160931.0
# Angola                                    7764.0
#                                           ...
# Venezuela, Bolivarian Republic of...      6384.0
# Viet Nam                                 11892.0
# Yemen                                    11940.0
# Zambia                                    5040.0
# Zimbabwe                                 19200.0
# Name: SalaryUSD, Length: 179, dtype: float64

# %%
country_grp['SalaryUSD'].median().loc['Germany']
# Out:
# 63016.0

# %% [markdown]
# ### Aggregated values

# %%
country_grp['SalaryUSD'].agg(['median', 'mean'])
# Out:
#                                         median           mean
# Country
# Afghanistan                             6222.0  101953.333333
# Albania                                10818.0   21833.700000
# Algeria                                 7878.0   34924.047619
# Andorra                               160931.0  160931.000000
# Angola                                  7764.0    7764.000000
# ...                                        ...            ...
# Venezuela, Bolivarian Republic of...    6384.0   14581.627907
# Viet Nam                               11892.0   17233.436782
# Yemen                                  11940.0   16909.166667
# Zambia                                  5040.0   10075.375000
# Zimbabwe                               19200.0   34046.666667
#
# [179 rows x 2 columns]

# %%
country_grp['SalaryUSD'].agg(['median', 'mean']).loc['Canada']
# Out:
# median     68705.000000
# mean      134018.564909
# Name: Canada, dtype: float64

# %% [markdown]
# How many peoples from United States worked with Python language.

# %% [markdown]
# Using filter method

# %%
filt = df['Country'] == 'United States'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 10083

# %% [markdown]
# Using groupby method

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
country_respondent = df['Country'].value_counts()

# %%
counting_using_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())

# %%
python_df = pd.concat([country_respondent, counting_using_python], axis='columns', sort=False)
python_df
# Out:
#                                   Country  LanguageWorkedWith
# United States                       20949               10083
# India                                9061                3105
# Germany                              5866                2451
# United Kingdom                       5737                2384
# Canada                               3395                1558
# ...                                   ...                 ...
# North Korea                             1                   0
# Niger                                   1                   1
# Saint Vincent and the Grenadines        1                   0
# Chad                                    1                   0
# Brunei Darussalam                       1                   0
#
# [179 rows x 2 columns]

# %%
python_df.rename(columns={'Country':'NumPrespondents', 'LanguageWorkedWith':'NumKnowsPython'}, inplace=True)

# %%
python_df
# Out:
#                                   NumPrespondents  NumKnowsPython
# United States                               20949           10083
# India                                        9061            3105
# Germany                                      5866            2451
# United Kingdom                               5737            2384
# Canada                                       3395            1558
# ...                                           ...             ...
# North Korea                                     1               0
# Niger                                           1               1
# Saint Vincent and the Grenadines                1               0
# Chad                                            1               0
# Brunei Darussalam                               1               0
#
# [179 rows x 2 columns]

# %%
python_df['PctKnowsPython'] = python_df['NumKnowsPython'] / python_df['NumPrespondents'] * 100

# %%
python_df
# Out:
#                                   NumPrespondents  NumKnowsPython  \
# United States                               20949           10083
# India                                        9061            3105
# Germany                                      5866            2451
# United Kingdom                               5737            2384
# Canada                                       3395            1558
# ...                                           ...             ...
# North Korea                                     1               0
# Niger                                           1               1
# Saint Vincent and the Grenadines                1               0
# Chad                                            1               0
# Brunei Darussalam                               1               0
#
#                                   PctKnowsPython
# United States                          48.131176
# India                                  34.267741
# ...

# %% [markdown]
# --------------

# %% [markdown]
# ## 9. Cleaning Data - Casting Datatypes and Handling Missing Values

# %%
people = {
    'first': ['Corey', 'Jane', 'John', 'Chris', np.nan, None, 'NA'], 
    'last': ['Schafer', 'Doe', 'Doe', 'Schafer', np.nan, np.nan, 'Missing'], 
    'email': ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com', None, np.nan, 'Anonymous@email.com', 'NA'],
    'age': ['33', '55', '63', '36', None, None, 'Missing']
}

people_df = pd.DataFrame(people)

# %%
people_df
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
people_df.dropna()
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 6     NA  Missing                       NA  Missing

# %% [markdown]
# dropna(axis='index', how='any')
#
# In this the code will go through the rows and drop row which have na value in any coloumn.

# %%
people_df.dropna(axis='index', how='any')
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 6     NA  Missing                       NA  Missing

# %%
# Remove the row if it have na in all the columns.

people_df.dropna(axis='index', how='all')
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
people_df.dropna(axis='columns', how='all')
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
people_df.dropna(axis='columns', how='any')
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5, 6]

# %% [markdown]
# ### Remove only from some missing columns

# %%
people_df.dropna(axis='index', how='any', subset=['email'])
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
people_df.dropna(axis='index', how='all', subset=['last', 'email'])
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %% [markdown]
# ### Replacing missing values by nan while creating dataframe

# %%
people_df = pd.DataFrame(people)

people_df.replace('NA', np.nan, inplace=True)
people_df.replace('Missing', np.nan, inplace=True)

people_df
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        JohnDoe@email.com    63
# 3  Chris  Schafer                     None    36
# 4    NaN      NaN                      NaN  None
# 5   None      NaN      Anonymous@email.com  None
# 6    NaN      NaN                      NaN   NaN

# %%
people_df.isna()
# Out:
#    first   last  email    age
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False   True  False
# 4   True   True   True   True
# 5   True   True  False   True
# 6   True   True   True   True

# %% [markdown]
# ### Fill na values

# %%
people_df.fillna('MISSING')
# Out:
#      first     last                    email      age
# 0    Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1     Jane      Doe        JaneDoe@email.com       55
# 2     John      Doe        JohnDoe@email.com       63
# 3    Chris  Schafer                  MISSING       36
# 4  MISSING  MISSING                  MISSING  MISSING
# 5  MISSING  MISSING      Anonymous@email.com  MISSING
# 6  MISSING  MISSING                  MISSING  MISSING

# %% [markdown]
# ### Casting

# %%
people_df.dtypes
# Out:
# first    object
# last     object
# email    object
# age      object
# dtype: object

# %%
people_df['age'] = people_df['age'].astype(float)

# %%
people_df.dtypes
# Out:
# first     object
# last      object
# email     object
# age      float64
# dtype: object

# %%
people_df.mean()
# Out:
# C:\Users\Suraj\AppData\Local\Temp\ipykernel_9040\4100048241.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   people_df.mean()
# age    46.75
# dtype: float64

# %% [markdown]
# -------------------

# %% [markdown]
# ### Stackoverflow data

# %%
# Create a custom list of all missing values

na_vals = ['NA', 'Missing']
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent', na_values=na_vals)

# %% [markdown]
# Calculate average years of experience

# %%
df['YearsCode'] = df['YearsCode'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [186], in <cell line: 1>()
# ----> 1 df['YearsCode'] = df['YearsCode'].astype(float)
#
# File D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
df['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 'Less than 1 year', '30', '9', '26', '40', '19',
#        '15', '20', '28', '25', '1', '22', '11', '33', '50', '41', '18',
#        '34', '24', '23', '42', '27', '21', '36', '32', '39', '38', '31',
#        '37', 'More than 50 years', '29', '44', '45', '48', '46', '43',
#        '47', '49'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year', 0, inplace=True)
df['YearsCode'].replace('More than 50 years', 51, inplace=True)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# 11.662114216834588

# %%
df['YearsCode'].median()
# Out:
# 9.0

# %% [markdown]
# -----------------

# %% [markdown]
# ## 10. Working with Dates and Time Series Data

# %% [markdown]
# ## 11. Reading/Writing Data to Different Sources
